# %%
import pandas as p


today = p.read_json('http://data.nba.net/prod/v4/today.json', orient='columns')
today
# Out:
#                                                        _internal  \
# allstarRoster                                                NaN
# anchorDate                                                   NaN
# boxscore                                                     NaN
# calendar                                                     NaN
# currentDate                                                  NaN
# currentScoreboard                                            NaN
# eventName                                              noon_roll
# gameBookPdf                                                  NaN
# leadTracker                                                  NaN
# leagueConfStandings                                          NaN
# leagueDivStandings                                           NaN
# leagueLastFiveGameTeamStats                                  NaN
# leagueMiniStandings                                          NaN
# ...

# %%
frame = p.read_json('http://data.nba.net/prod/v1/2018/players.json', orient='columns')
list = frame['league']['standard']
frame2 = p.DataFrame(list)
frame2.set_index("personId",inplace = True)
frame2.to_csv('players.csv')
# Out:
# [{'firstName': 'Alex',
#   'lastName': 'Abrines',
#   'personId': '203518',
#   'teamId': '1610612760',
#   'jersey': '8',
#   'isActive': True,
#   'pos': 'G',
#   'heightFeet': '6',
#   'heightInches': '6',
#   'heightMeters': '1.98',
#   'weightPounds': '200',
#   'weightKilograms': '90.7',
#   'dateOfBirthUTC': '1993-08-01',
#   'teams': [{'teamId': '1610612760',
#     'seasonStart': '2016',
#     'seasonEnd': '2018'}],
#   'draft': {'teamId': '1610612760',
#    'pickNum': '32',
#    'roundNum': '2',
#    'seasonYear': '2013'},
#   'nbaDebutYear': '2016',
#   'yearsPro': '2',
#   'collegeName': '',
#   'lastAffiliation': 'Spain/Spain',
#   'country': 'Spain'},
#  {'firstName': 'Quincy',
#   'lastName': 'Acy',
#   'personId': '203112',
#   'teamId': '1610612756',
#   'jersey': '4',
#   'isActive': True,
#   'pos': 'F',
#   'heightFeet': '6',
#   'heightInches': '7',
#   'heightMeters': '2.01',
#   'weightPounds': '240',
#   'weightKilograms': '108.9',
# ...

# %%
# Out:
#                        collegeName         country dateOfBirthUTC  \
# personId
# 203518                                       Spain     1993-08-01
# 203112                      Baylor             USA     1990-10-06
# 1629121            St. Bonaventure             USA     1996-05-04
# 203500                  Pittsburgh     New Zealand     1993-07-20
# 1628389                   Kentucky             USA     1997-07-18
# 1629061                                South Sudan     1997-02-01
# 200746                       Texas             USA     1985-07-19
# 1628959                                        USA     1997-10-29
# 1628960                       Duke             USA     1995-10-08
# 1628386                      Texas             USA     1998-04-21
# 1628443                    Arizona             USA     1993-01-15
# 202329                 Wake Forest             USA     1990-09-21
# 1626147                   Virginia             USA     1993-11-19
# ...
